# %%
import pandas as pd
import numpy as np

# %%
from selenium import webdrive
from selenium.webdriver import ActionChains as AC
from tqdm import tqdm
from tqdm import tqdm_notebook
import re
from time import sleep
import time

# %%
pwd
# Out:
# 'C:\\Users\\clubc\\Desktop\\python_basic'

# %%
# 크롬창 띄우기
driver = webdriver.Chrome("chromedriver.exe")  # 크롬 드라이버 로드
driver.get("https://www.kurly.com/shop/goods/goods_list.php?category=038")
time.sleep(3)

# %%
#사진
overlays1 = '.img > img' 
imgs = driver.find_elements_by_css_selector(overlays1)
pic = imgs[0].get_attribute('src')
pic
# Out:
# 'https://img-cf.kurly.com/shop/data/goods/159420047029l0.jpg'

# %%
#상품명
overlays2 = ".info > .name"
item_titles = driver.find_elements_by_css_selector(overlays2)
title = item_titles[0].text
title
# Out:
# '[농부의 꽃] 노란 백합 5송이 이상'

# %%
#가격
overlays3 = ".info > .cost"
costs = driver.find_elements_by_css_selector(overlays3)
cost = costs[0].text
cost
# Out:
# '15,900원'

# %%
dict1 = {}

for i in range(len(imgs)):
    target_info = {}
    overlays2 = ".info > .name"
    item_titles = driver.find_elements_by_css_selector(overlays2)
    title = item_titles[i].text
    target_info['title'] = title

    overlays1 = '.img > img'
    imgs = driver.find_elements_by_css_selector(overlays1)
    pic = imgs[i].get_attribute('src')
    target_info['pic'] = pic

    overlays3 = ".info > .cost"
    costs = driver.find_elements_by_css_selector(overlays3)
    cost = costs[i].text
    target_info['cost'] = cost

    dict1[i] = target_info            # 토탈 딕셔너리로 만들기

    print("{0}".format(i), title)
# Out:
# 0 [농부의 꽃] 노란 백합 5송이 이상
# 1 [마스터푸드] 민트젤리
# 2 저탄소 GAP 스테비 황도 복숭아 2kg
# 3 [화식한우] 1등급 이상 한우 양지 200g(냉장)
# 4 [화식한우] 1등급 이상 한우 불고기 200g(냉장)
# 5 [화식한우] 1등급 이상 한우 채끝 스테이크용 300g
# 6 [화식한우] 1등급 이상 한우 안심 200g(냉장)
# 7 [화식한우] 1등급 이상 한우 사태 200g(냉장)
# 8 [화식한우] 1등급 이상 한우 양지 세절육 200g(냉장)
# 9 [화식한우] 1등급 이상 한우 부채살 칼집 200g(냉장)
# 10 [씨투게더] 미역귀 장아찌
# 11 [씨투게더] 미역줄기 장아찌
# 12 [바븐] 완도 꼬마문어 400g 내외(생물)
# 13 [바븐] 깨끗하게 손질된 제주 황돔 300g 내외(생물)
# 14 [씨투게더] 다시마 장아찌
# 15 [씨투게더] 곰피미역 장아찌
# 16 [그리다꿈] 리얼 딸기라떼 2종
# 17 [그리다꿈] 리얼 바나나라떼 2종
# 18 [그리다꿈] 리얼 딸기베이스
# 19 [화식한우] 1등급 이상 한우 등심 구이용 200g(냉장)
# 20 [화식한우] 1등급 이상 한우 꽃등심 구이용 200g(냉장)
# 21 [경주축협] 경주천년한우 1++등급 등심 200g
# 22 [경주축협] 경주천년한우 1++등급 안심 200g
# 23 [경주축협] 경주천년한우 1++등급 채끝 200g
# 24 [경주축협] 경주천년한우 1++등급 갈비살 200g
# 25 [경주축협] 경주천년한우 1++등급 업진살 200g
# 26 [경주축협] 경주천년한우 1++등급 치마살 200g
200g', 'pic': 'https://img-cf.kurly.com/shop/data/goods/1595223527868l0.jpg', 'cost': '37,500원'}, 22: {'title': '[경주축협] 경주천년한우 1++등급 안심 200g', 'pic': 'https://img-cf.kurly.com/shop/data/goods/159522456174l0.jpg', 'cost': '41,900원'}, 23: {'title': '[경주축협] 경주천년한우 1++등급 채끝 200g', 'pic': 'https://img-cf.kurly.com/shop/data/goods/1595225520259l0.jpg', 'cost': '39,300원'}, 24: {'title': '[경주축협] 경주천년한우 1++등급 갈비살 200g', 'pic': 'https://img-cf.kurly.com/shop/data/goods/1595227165529l0.jpg', 'cost': '39,800원'}, 25: {'title': '[경주축협] 경주천년한우 1++등급 업진살 200g', 'pic': 'https://img-cf.kurly.com/shop/data/goods/1595231005127l0.jpg', 'cost': '35,000원'}, 26: {'title': '[경주축협] 경주천년한우 1++등급 치마살 200g', 'pic': 'https://img-cf.kurly.com/shop/data/goods/1595229288408l0.jpg', 'cost': '45,600원'}, 27: {'title': '[경주축협] 경주천년한우 1++등급 부채살 200g', 'pic': 'https://img-cf.kurly.com/shop/data/goods/1595230009167l0.jpg', 'cost': '36,800원'}, 28: {'title': '[경주축협] 경주천년한우 1++등급 불고기 200g', 'pic': 'https://img-cf.kurly.com/shop/data/goods/1595231948202l0.jpg', 'cost': '15,800원'}, 29: {'title': '[고려은단] 수면비법', 'pic': 'https://img-cf.kurly.com/shop/data/goods/1595211997173l0.jpg', 'cost': '79,900원 → 75,905원'} ...

# %%
result_df = pd.DataFrame.from_dict(dict1, 'index')
result_df
# Out:
#                                             title  \
# 0                            [농부의 꽃] 노란 백합 5송이 이상
# 1                                    [마스터푸드] 민트젤리
# 2                          저탄소 GAP 스테비 황도 복숭아 2kg
# 3                    [화식한우] 1등급 이상 한우 양지 200g(냉장)
# 4                   [화식한우] 1등급 이상 한우 불고기 200g(냉장)
# 5                  [화식한우] 1등급 이상 한우 채끝 스테이크용 300g
# 6                    [화식한우] 1등급 이상 한우 안심 200g(냉장)
# 7                    [화식한우] 1등급 이상 한우 사태 200g(냉장)
# 8                [화식한우] 1등급 이상 한우 양지 세절육 200g(냉장)
# 9                [화식한우] 1등급 이상 한우 부채살 칼집 200g(냉장)
# 10                                 [씨투게더] 미역귀 장아찌
# 11                                [씨투게더] 미역줄기 장아찌
# 12                       [바븐] 완도 꼬마문어 400g 내외(생물)
# 13                [바븐] 깨끗하게 손질된 제주 황돔 300g 내외(생물)
# 14                                 [씨투게더] 다시마 장아찌
# 15                                [씨투게더] 곰피미역 장아찌
# 16                              [그리다꿈] 리얼 딸기라떼 2종
# 17                             [그리다꿈] 리얼 바나나라떼 2종
# 18                                [그리다꿈] 리얼 딸기베이스
# 19               [화식한우] 1등급 이상 한우 등심 구이용 200g(냉장)
# 20              [화식한우] 1등급 이상 한우 꽃등심 구이용 200g(냉장)
# 21                    [경주축협] 경주천년한우 1++등급 등심 200g
# 22                    [경주축협] 경주천년한우 1++등급 안심 200g
# 23                    [경주축협] 경주천년한우 1++등급 채끝 200g
# 24                   [경주축협] 경주천년한우 1++등급 갈비살 200g
# 25                   [경주축협] 경주천년한우 1++등급 업진살 200g
# 26                   [경주축협] 경주천년한우 1++등급 치마살 200g
# 27                   [경주축협] 경주천년한우 1++등급 부채살 200g
# 28                   [경주축협] 경주천년한우 1++등급 불고기 200g
# 29                                    [고려은단] 수면비법
# ..                                            ...
# 69                                      황도 복숭아 2입
# 70                                      백도 복숭아 2입
# 71                              [네이쳐패스] 치타촘스 284g
# 72                       [크래프트하인즈] 싱글즈 슬라이스 치즈 2종
# 73                                 [화오미] 고추잡채와 꽃빵
# 25  https://img-cf.kurly.com/shop/data/goods/15952...              35,000원
# 26  https://img-cf.kurly.com/shop/data/goods/15952...              45,600원
# 27  https://img-cf.kurly.com/shop/data/goods/15952...              36,800원
# 28  https://img-cf.kurly.com/shop/data/goods/15952...              15,800원
# 29  https://img-cf.kurly.com/shop/data/goods/15952...    79,900원 → 75,905원
# ..                                                ...                  ...
# 69  https://img-cf.kurly.com/shop/data/goods/15947...               5,490원
# 70  https://img-cf.kurly.com/shop/data/goods/15947...               5,490원
# 71  https://img-cf.kurly.com/shop/data/goods/15943...      6,980원 → 6,631원
# 72  https://img-cf.kurly.com/shop/data/goods/15949...      3,780원 → 3,402원
# 73  https://img-cf.kurly.com/shop/data/goods/15947...               7,900원
# 74  https://img-cf.kurly.com/shop/data/goods/14718...               7,500원
# 75  https://img-cf.kurly.com/shop/data/goods/15948...               4,450원
# 76  https://img-cf.kurly.com/shop/data/goods/15948...               2,450원
# 77  https://img-cf.kurly.com/shop/data/goods/15936...               4,300원
# 78  https://img-cf.kurly.com/shop/data/goods/15936...               4,300원
# 79  https://img-cf.kurly.com/shop/data/goods/15936...               4,300원
# 80  https://img-cf.kurly.com/shop/data/goods/15949...               8,490원
# 81  https://img-cf.kurly.com/shop/data/goods/15948...               6,900원
# 82  https://img-cf.kurly.com/shop/data/goods/15948...               5,900원
# 83  https://img-cf.kurly.com/shop/data/goods/15948...               5,900원
# 84  https://img-cf.kurly.com/shop/data/goods/15948...               4,590원
# 85  https://img-cf.kurly.com/shop/data/goods/15948...               6,900원
# 86  https://img-cf.kurly.com/shop/data/goods/15947...              40,000원
# 87  https://img-cf.kurly.com/shop/data/goods/15948...               2,900원
# 88  https://img-cf.kurly.com/shop/data/goods/15949...               1,790원
# 89  https://img-cf.kurly.com/shop/data/goods/15948...    16,100원 → 14,490원
# 90  https://img-cf.kurly.com/shop/data/goods/15948...               5,500원
# 91  https://img-cf.kurly.com/shop/data/goods/15947...      5,700원 → 5,130원
# 92  https://img-cf.kurly.com/shop/data/goods/15948...               4,800원
# 93  https://img-cf.kurly.com/shop/data/goods/15948...               6,500원
# 94  https://img-cf.kurly.com/shop/data/goods/15948...               6,000원
# 95  https://img-cf.kurly.com/shop/data/goods/15948...               2,900원
# 96  https://img-cf.kurly.com/shop/data/goods/15948...  299,000원 → 257,140원
# 97  https://img-cf.kurly.com/shop/data/goods/15948...  149,000원 → 111,750원
# 98  https://img-cf.kurly.com/shop/data/goods/15948...               9,990원
#
# [99 rows x 3 columns]

# %%
n = result_df['pic'].count()
result_df.to_csv("data/kurly({}).csv".format('컬리'), encoding='euc-kr')

# %%
# url = items.get_attribute('href')
# url

# %%
num_pic = len(result_df['pic'])
num_pic
# Out:
# 99

# %%
# 이미지들 image 폴더에 다운받기
import urllib.request

for i in range(0, 99):
    try:
        index = result_df['pic'][i]
        urllib.request.urlretrieve(index, "image/kurly{0}.jpg".format(i))
    except:
        pass

# %%
url = navs[0].get_attribute('href')
url
# Out:
# 'https://mail.naver.com/'

# %% [raw]
# # 셀레늄에서 데이터 찾는 함수
# .get_attribute
# .text

# %% [raw]
# 딕셔너리, 리스트에 저장하는 것만 익숙해지면 크롤링
